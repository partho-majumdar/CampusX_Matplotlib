# %%
import numpy as np # type: ignore
import pandas as pd # type: ignore
import matplotlib.pyplot as plt  # type: ignore
import seaborn as sns # type: ignore

# %%
# colored scatter plot

iris = pd.read_csv("./iris.csv")
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'])
plt.xlabel("Sepal length")
plt.ylabel("Petal length")
# Out:
# Text(0, 0.5, 'Petal length')

# %%
iris['Species'] = iris['Species'].replace({
    'Iris-setosa': 0,
    'Iris-versicolor': 1,
    'Iris-virginica': 2
})
iris.sample(5)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_12228\1721870541.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species'] = iris['Species'].replace({
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 32    33            5.2           4.1            1.5           0.1        0
# 81    82            5.5           2.4            3.7           1.0        1
# 17    18            5.1           3.5            1.4           0.3        0
# 6      7            4.6           3.4            1.4           0.3        0
# 115  116            6.4           3.2            5.3           2.3        2

# %%
# plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'])
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'])
plt.xlabel("Sepal length")
plt.ylabel("Petal length")
# Out:
# Text(0, 0.5, 'Petal length')

# %%
# for changing color 
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'], cmap = 'viridis')
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'], cmap = 'summer')
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'], cmap = 'jet')
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'], cmap = 'magma')
plt.xlabel("Sepal length")
plt.ylabel("Petal length")
# Out:
# Text(0, 0.5, 'Petal length')

# %%
# colorbar -> which color represent which value 

plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'], cmap = 'jet')
plt.xlabel("Sepal length")
plt.ylabel("Petal length")
plt.colorbar()

# %%
# alpha -> control graph opacity

plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'], cmap = 'jet', alpha = 0.3)
plt.xlabel("Sepal length")
plt.ylabel("Petal length")
plt.colorbar()

# %%
# plot size 

plt.figure(figsize = (15, 5)) # width = 15, height = 5 (applicable for all graph)
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c = iris['Species'], cmap = 'jet', alpha = .5)
plt.xlabel("Sepal length")
plt.ylabel("Petal length")
plt.colorbar()

# %%
# ------------------- Annotations (place a text in a graph)

batters = pd.read_csv('./batter.csv')
sample_df = batters.head(100).sample(25, random_state = 5)
# sample_df = batters.head(100)
plt.scatter(sample_df['avg'], sample_df['strike_rate']) # here don't know which point represent which batsman use annotation

# %%
x = [1, 2, 3, 4]
y = [5, 6, 7, 8]

plt.scatter(x, y)
plt.text(1, 5, 'point1')
plt.text(2, 6, 'point2')
plt.text(3, 7, 'point3')
plt.text(4, 8, 'point4', fontdict = {
    'size': 12,
    'color': 'brown'
})
# Out:
# Text(4, 8, 'point4')

# %%
plt.figure(figsize = (18, 9))
plt.scatter(sample_df['avg'], sample_df['strike_rate'])
plt.xlabel('avg')
plt.ylabel('strike_rate')

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])

# %%
# according to run point size decide 

plt.figure(figsize = (18, 9))
plt.scatter(sample_df['avg'], sample_df['strike_rate'], s = sample_df['runs'])
plt.xlabel('avg')
plt.ylabel('strike_rate')

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])

# %%
# Horizontal (axhline) vs Vertical (axvline) lines

plt.figure(figsize = (18, 9))
plt.scatter(sample_df['avg'], sample_df['strike_rate'], s = sample_df['runs'])
plt.xlabel('avg')
plt.ylabel('strike_rate')

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])

plt.axhline(130, color = 'red')
plt.axhline(140, color = 'green')
plt.axvline(30, color = 'red')

# %%
# --------------------- Subplots

# second way of plotting graph

# plt.subplots() # give me two default value --> fig(graph) & axis
fig, ax = plt.subplots(figsize = (15, 9))
ax.scatter(batters['avg'], batters['strike_rate'], color = 'red', marker = '+')
ax.set_title("Avg vs strike rate graph")
ax.set_xlabel("Avg")
ax.set_ylabel("Strike-rate")
ax.axhline(150, color = 'green')
ax.axvline(30, color = 'yellow')
plt.show()

# %%
# draw side by side two multiple graph (avg vs strike rate) & (runs vs strike rate)

batters.head()
fig, ax = plt.subplots(nrows = 2, ncols = 1, figsize = (20, 10), sharex = True) # sharex = True (only show value in x co-ordinate)
ax[0].scatter(batters['avg'], batters['strike_rate'], color = 'red', marker = '+')
ax[1].scatter(batters['avg'], batters['runs'], color = 'green')

ax[0].set_title("Avg vs strike rate")
ax[0].set_xlabel("Avg")
ax[0].set_ylabel("Strike rate")

ax[1].set_title("Avg vs runs")
ax[1].set_xlabel("Avg")
ax[1].set_ylabel("total runs")

plt.show()

# %%
# 4 box with 2 row, and 2 col
''' 
2D array 
    - (0, 0) -> first box 
    - (0, 1) -> second box 
    - (1, 0) -> third box 
    - (1, 1) -> fourth box  
'''

fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (20, 10))

ax[0, 0].scatter(batters['avg'], batters['strike_rate'], color = 'red')
ax[0, 1].scatter(batters['avg'], batters['runs'], color = 'green')
ax[1, 0].hist(batters['avg'], color = 'pink')
ax[1, 1].hist(batters['runs'], color = 'brown')

plt.show()

# %%
# Second way to do the same thing

fig = plt.figure(figsize = (20, 10))

ax1 = fig.add_subplot(2, 2, 1) # 2 row, 2 col, 1st graph
ax1.scatter(batters['avg'], batters['strike_rate'], color = 'red')

ax2 = fig.add_subplot(2, 2, 2) # 2 row, 2 col, 2nd graph
ax2.hist(batters['runs'], color = 'brown')

ax3 = fig.add_subplot(2, 2, 3) # 2 row, 2 col, 3rd graph
ax3.scatter(batters['avg'], batters['runs'], color = 'green')

ax4 = fig.add_subplot(2, 2, 4) # 2 row, 2 col, 4th graph
ax4.hist(batters['avg'], color = 'pink')

plt.show()

# %%
# -------------------- 3D graph

fig = plt.figure(figsize = (20, 10))
ax = plt.subplot(projection = '3d')
ax.scatter3D(batters['runs'], batters['avg'], batters['strike_rate'])

ax.set_title("IPL batsman run analysis")
ax.set_xlabel("runs")
ax.set_ylabel("avg")
ax.set_zlabel("strike_rate")
# Out:
# Text(0.5, 0, 'strike_rate')

# %%
# 3D line plot

x = [0, 1, 5, 25]
y = [0, 10, 13, 0]
z = [0, 13, 20, 9]

fig = plt.figure()
ax = plt.subplot(projection = '3d')

ax.scatter3D(x, y, z, s = [100, 100, 100, 100])
ax.plot3D(x, y, z)
plt.show()

# %%
# ------------------------ 3D Surface plot

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

xx, yy = np.meshgrid(x, y)
z = (xx ** 2) + (yy ** 2)

fig = plt.figure(figsize = (20, 10))
ax = plt.subplot(projection = '3d')
p = ax.plot_surface(xx, yy, z, cmap = 'viridis')
fig.colorbar(p)

# %%
z = np.sin(xx) + np.cos(yy)
fig = plt.figure(figsize = (20, 10))
ax = plt.subplot(projection = '3d')
p = ax.plot_surface(xx, yy, z, cmap = 'viridis')
fig.colorbar(p)
plt.show()

# %%
# Contour graph -> represent 3d graph into a 2d graph

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

xx, yy = np.meshgrid(x, y)
z = (xx ** 2) + (yy ** 2)

fig = plt.figure(figsize = (10, 8))
ax = plt.subplot()
ax = plt.subplot(projection = '3d')
p = ax.contour(xx, yy, z, cmap = 'viridis')
fig.colorbar(p)
plt.show()

# %%
# contourf -> filled contour

x = np.linspace(-10, 10, 100)
y = np.linspace(-10, 10, 100)

xx, yy = np.meshgrid(x, y)
z = (xx ** 2) + (yy ** 2)

fig = plt.figure(figsize = (10, 8))
ax = plt.subplot()
p = ax.contourf(xx, yy, z, cmap = 'viridis')
fig.colorbar(p)
plt.show()

# %%
z = np.sin(xx) + np.cos(yy)
fig = plt.figure(figsize = (10, 8))
ax = plt.subplot()
# ax = plt.subplot(projection = '3d')
p = ax.contourf(xx, yy, z, cmap = 'viridis')
fig.colorbar(p)
plt.show()

# %%
# Heatmap -> how value is distributed (compare 2 categorical data)

delivery = pd.read_csv('./IPL_Ball_by_Ball_2008_2022.csv')
temp_df = delivery[(delivery['ballnumber'].isin([1, 2, 3, 4, 5, 6])) & (delivery['batsman_run'] == 6)]

grid = temp_df.pivot_table(index = 'overs', columns = 'ballnumber', values = 'batsman_run', aggfunc = 'count')
plt.figure(figsize = (10, 8))
plt.imshow(grid)
plt.yticks(delivery['overs'].unique(), list(range(1, 21)))
plt.xticks(np.arange(0, 6), list(range(1, 7)))
plt.colorbar()

# %%
# ----------------- Dataframe plot (inside pandas i can use matplotlib graph)

# work on series

s = pd.Series([1, 2, 3, 4, 5, 6])
# s.plot(kind = 'line')
# s.plot(kind = 'hist')
s.plot(kind = 'pie')
# Out:
# <Axes: >

# %%
# work with dataframe

tips = sns.load_dataset('tips')

# Scatter plot 
tips['size'] = tips['size'] * 100
# tips.plot(kind = 'scatter', x = 'total_bill', y = 'tip', title = 'Cost analysis', color = 'red', marker = '+', figsize = (10, 8), s = 'size')
tips.plot(kind = 'scatter', x = 'total_bill', y = 'tip', title = 'Cost analysis', marker = '+', figsize = (10, 8), s = 'size', c = 'sex', cmap = 'viridis')
plt.show()

# %%
# 2d plot 

stocks = pd.read_csv('https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv')

# line plot
stocks['MSFT'].plot(kind = 'line')
# Out:
# <Axes: >

# %%
# line plot for all
 
stocks.plot(kind = 'line', x = 'Date')
# Out:
# <Axes: xlabel='Date'>

# %%
# line plot for facebook and microsoft

stocks[['Date', 'FB', 'AAPL']].plot(kind = 'line', x = 'Date')
# Out:
# <Axes: xlabel='Date'>

# %%
# single bar chart

temp = pd.read_csv('./batsman_season_record.csv')
temp['2015'].plot(kind = 'bar')
plt.show()

# %%
# avg total bill for male and avg total bill for female

tips.groupby('sex', observed = False)['total_bill'].mean().plot(kind = 'bar')
plt.show()

# %%
temp.plot(kind = 'bar')
plt.show()

# %%
# stacked bar chart

temp.plot(kind = 'bar', stacked = True)
# Out:
# <Axes: >

# %%
# histogram

stocks.plot(kind = 'hist') # print 3
plt.show()

# %%
# print only 2 

stocks[['FB', "MSFT"]].plot(kind = 'hist', bins = 40)
plt.show()

# %%
# pie chart (single and multiple)

df = pd.DataFrame(
    {
        'batsman':['Dhawan','Rohit','Kohli','SKY','Pandya','Pant'],
        'match1':[120, 90, 35, 45, 12, 10],
        'match2':[0, 1, 123, 130, 34, 45],
        'match3':[50, 24, 145, 45, 10, 90]
    }
)

df.head()
df['match1'].plot(kind = 'pie', labels = df['batsman'].values, autopct = '%0.1f')
plt.show()

# %%
# multiple pie chart

df[['match1', 'match2', 'match3']].plot(kind = 'pie', subplots = True, figsize = (20, 10))
plt.show()

# %%
# multiple separate graph together

stocks.plot(kind = 'line', subplots = True, figsize = (20, 10))
plt.show()

# %%
# line plot on multi-index dataframe

tips.pivot_table(index = ['day', 'time'], columns = ['sex', 'smoker'], values = 'total_bill', aggfunc = 'mean', observed = True).plot(kind = 'line', figsize = (20, 10))
plt.show()

# %%
# bar plot on multi-index dataframe

tips.pivot_table(index = ['day', 'time'], columns = ['sex', 'smoker'], values = 'total_bill', aggfunc = 'mean', observed = True).plot(kind = 'bar', figsize = (20, 10))
plt.show()

# %%
# pie chart on multi-index dataframe

tips.pivot_table(index = ['day', 'time'], columns = ['sex', 'smoker'], values = 'total_bill', aggfunc = 'mean', observed = True).plot(kind = 'pie', subplots = True, figsize = (40, 10), autopct = '%0.1f')
plt.show()
